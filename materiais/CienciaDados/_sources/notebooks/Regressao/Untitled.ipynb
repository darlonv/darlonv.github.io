# %% [markdown]
# # Exercícios

# %% [markdown]
# Considerando a base de dados do ENEM de 2018, a partir da nota da redação, estime as seguintes notas:
# - Demonstrar domínio da modalidade escrita formal da Língua

# %%
import pandas as pd

# %%
colunas = ['NU_NOTA_REDACAO',
           'NU_NOTA_COMP1',
           'NU_NOTA_COMP2',
           'NU_NOTA_COMP3',
           'NU_NOTA_COMP4',
           'NU_NOTA_COMP5']

# %%
base = pd.read_csv('/home/darlon/Pesquisa/bases/Brasil/ENEM/2018/MICRODADOS_ENEM_2018.csv.tar.gz', sep=';', encoding='latin-1')

# %%
nb = base[colunas].copy()
del(base)
base = nb

# %%
base.plot.scatter('NU_NOTA_REDACAO', 'NU_NOTA_COMP5')

# %%
import pandas as pd

# %%
base = pd.read_csv('/home/darlon/Pesquisa/bases/Brasil/PRF/Infracoes/infracoes_2020.zip', sep=';')
# Out:
# /home/darlon/disk/home/darlon/Pesquisa/env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483758 entries, 0 to 483757
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Número do Auto                 483758 non-null  object
#  1   Data da Infração (DD/MM/AAAA)  483758 non-null  object
#  2   Indicador de Abordagem         483758 non-null  object
#  3   Assinatura do Auto             483758 non-null  object
#  4   Indicador Veiculo Estrangeiro  483758 non-null  object
#  5   Sentido Trafego                483758 non-null  object
#  6   UF Placa                       483758 non-null  object
#  7   UF Infração                    483758 non-null  object
#  8   BR Infração                    483758 non-null  int64
#  9   Km Infração                    483758 non-null  int64
#  10  Município                      483758 non-null  object
#  11  Código da Infração             483758 non-null  int64
# ...

# %%
base.head()
# Out:
#     Número do Auto Data da Infração (DD/MM/AAAA) Indicador de Abordagem  \
# 0  2b0d033ac754fc6                    2020-01-16                      S
# 1  e1f8917e70ebf38                    2020-01-18                      S
# 2  dfd71eeac1fe06b                    2020-01-25                      C
# 3  558685c5e4dbcca                    2020-01-30                      C
# 4  aac0a90d941bb4e                    2020-01-31                      C
#
#   Assinatura do Auto Indicador Veiculo Estrangeiro Sentido Trafego UF Placa  \
# 0                  N                             N               C       -1
# 1                  N                             N               C       -1
# 2                  N                             N               D       RS
# 3                  N                             N               C       GO
# 4                  N                             N               C       RJ
#
#   UF Infração  BR Infração  Km Infração  ...  \
# ...

# %%
alc = base[base['Medição Infração'] == 'Alcoolemia']

# %%
alc.head()
# Out:
#       Número do Auto Data da Infração (DD/MM/AAAA) Indicador de Abordagem  \
# 29   8e4e93652b7bdc2                    2020-01-19                      C
# 30   2b498ca1642022f                    2020-01-19                      C
# 94   1a87742bcbccd29                    2020-01-26                      C
# 151  97c00d009d8d2b8                    2020-01-18                      C
# 152  c689c23338e9dba                    2020-01-24                      C
#
#     Assinatura do Auto Indicador Veiculo Estrangeiro Sentido Trafego UF Placa  \
# 29                   N                             N               C       -1
# 30                   N                             N               C       RS
# 94                   N                             N               D       MS
# 151                  N                             N               C       AM
# 152                  N                             N               D       AM
#
#     UF Infração  BR Infração  Km Infração  ...  \
# ...

# %%
corr = alc['Medição Considerada']

# %%
corr.unique()
# Out:
# array(['0.19', '0.94', '0.00', '0.40', '0.38', '0.78', '0.82', '0.06',
#        '0.62', '0.84', '0.57', '0.23', '0.56', '0.03', '0.04', '0.20',
#        '0.09', '0.16', '1.08', '0.08', '1.14', '1.16', '0.44', '0.83',
#        '0.02', '0.76', '0.71', '0.95', '0.07', '0.11', '0.28', '0.74',
#        '0.41', '0.39', '0.18', '0.17', '0.29', '0.36', '0.55', '0.46',
#        '1.12', '0.51', '0.27', '0.65', '0.50', '0.34', '0.10', '0.42',
#        '0.14', '0.32', '0.49', '0.13', '0.90', '0.47', '0.45', '0.81',
#        '0.63', '0.21', '0.05', '0.25', '0.35', '0.72', '1.09', '0.77',
#        '0.12', '0.67', '0.26', '0.69', '0.97', '1.06', '0.22', '0.33',
#        '0.61', '0.54', '0.52', '0.24', '1.01', '0.98', '1.17', '1.18',
#        '1.07', '0.37', '0.15', '0.31', '0.53', '0.85', '0.66', '0.48',
#        '0.43', '1.02', '0.73', '0.88', '0.58', '0.01', '0.92', '0.96',
#        '0.91', '1.04', '0.93', '0.87', '0.30', '0.89', '0.64', '1.03',
# ...
